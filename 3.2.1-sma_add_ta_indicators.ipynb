# %% [markdown]
# Because of the dependencies' conflicts between `talib` and and `mlfinlab`, TA indicators' computation should be done in another environment.

# %%
import pandas as pd
import talib as ta

# %%
# %store -r df

# %%
df
# Out:
#                            close      low     high  dollar_volume  short_sma  \
# date_time
# 2018-01-01 00:11:11.241  13763.5  13675.0  13920.0   9.339762e+06        NaN
# 2018-01-01 00:27:14.652  13775.5  13596.0  13789.5   9.340538e+06        NaN
# 2018-01-01 00:48:23.395  13745.0  13657.0  13780.5   9.345154e+06        NaN
# 2018-01-01 01:09:43.777  13555.5  13555.5  13770.0   9.341081e+06        NaN
# 2018-01-01 01:32:03.253  13650.5  13550.0  13737.5   9.420639e+06        NaN
# ...                          ...      ...      ...            ...        ...
# 2019-04-30 22:56:45.216   5271.0   5264.5   5273.0   9.345586e+06   5251.225
# 2019-04-30 23:06:44.670   5270.0   5270.0   5275.5   9.349355e+06   5252.900
# 2019-04-30 23:14:24.220   5263.5   5263.5   5270.0   9.346254e+06   5254.050
# 2019-04-30 23:21:57.227   5257.5   5257.0   5266.0   9.353580e+06   5255.075
# 2019-04-30 23:34:40.947   5256.5   5256.5   5262.5   9.393172e+06   5256.300
#
# ...

# %%
df['rsi'] = ta.RSI(df.close.values)
df['willr'] = ta.WILLR(df.close.values, df.high.values, df.low.values)
df['macd'], _, _ = ta.MACD(df.close.values)
df['proc'] = ta.ROC(df.close.values)
df['obv'] = ta.OBV(df.close.values, df.dollar_volume.values)

# %%
df
# Out:
#                            close      low     high  dollar_volume  short_sma  \
# date_time
# 2018-01-01 00:11:11.241  13763.5  13675.0  13920.0   9.339762e+06        NaN
# 2018-01-01 00:27:14.652  13775.5  13596.0  13789.5   9.340538e+06        NaN
# 2018-01-01 00:48:23.395  13745.0  13657.0  13780.5   9.345154e+06        NaN
# 2018-01-01 01:09:43.777  13555.5  13555.5  13770.0   9.341081e+06        NaN
# 2018-01-01 01:32:03.253  13650.5  13550.0  13737.5   9.420639e+06        NaN
# ...                          ...      ...      ...            ...        ...
# 2019-04-30 22:56:45.216   5271.0   5264.5   5273.0   9.345586e+06   5251.225
# 2019-04-30 23:06:44.670   5270.0   5270.0   5275.5   9.349355e+06   5252.900
# 2019-04-30 23:14:24.220   5263.5   5263.5   5270.0   9.346254e+06   5254.050
# 2019-04-30 23:21:57.227   5257.5   5257.0   5266.0   9.353580e+06   5255.075
# 2019-04-30 23:34:40.947   5256.5   5256.5   5262.5   9.393172e+06   5256.300
#
# ...

# %%
# %store df
# Out:
# Stored 'df' (DataFrame)
